# %%
R=RootSystem(['B',3]); R
# Out:
# Root system of type ['B', 3]

# %%
R.root_lattice()
# Out:
# Root lattice of the Root system of type ['B', 3]

# %%
R.dynkin_diagram()
# Out:
# O---O=>=O
# 1   2   3
# B3

# %%
L = R.ambient_space(); L.plot(projection=False)
# Out:
# Graphics3d Object

# %%
L.plot(reflection_hyperplanes="all")
# Out:
# Graphics3d Object
